# %% [markdown]
# # Capstone Project - The Optimal Locations for Indian Restaurent
#
# ## Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_districts_and_neighborhoods_in_Los_Angeles
#
# ## 1. Importing Libraries

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import pandas.io.json
import requests
import json

from bs4 import BeautifulSoup

from geopy.geocoders import Nominatim

import geocoder
import folium

print('Libraries Imported')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-81-60f3a9cbb4cc> in <module>()
#      11
#      12 from geopy.geocoders import Nominatim
# ---> 13 import geocoder
#      14 import folium
#      15
#
# ModuleNotFoundError: No module named 'geocoder'

# %% [markdown]
# ## 2. Scrapping the Wikipedia page

# %%
# send the GET request to wikipedia page
data = requests.get("https://en.wikipedia.org/wiki/List_of_districts_and_neighborhoods_in_Los_Angeles").text

# %%
# parse data from html into beautifulsoup object
soup = BeautifulSoup(data, "html.parser")

# %%
# create a list to store neighborhood data
neighborhoodList = []

# %% [markdown]
# Parse the HTLM page using the BeautifulSoup and get the data
# For more info refere the [Python Tutorial: Web Scraping with BeautifulSoup and Requests](https://www.youtube.com/watch?v=ng2o98k983k&t=215s)

# %%
for i in range(4):
    for rows in soup.find_all('div', class_ = "div-col columns column-width")[i].findAll("li"):
        neighborhoodList.append(rows.text)

# %%
neighbor_df = pd.DataFrame({"Neighborhood":neighborhoodList})

# %% [markdown]
# Neighborhood column contens references, so we have to deal with that

# %%
neighbor_df['Neighborhood'] = neighbor_df["Neighborhood"].apply(lambda x: x.split('[')[0])

# %%
neighbor_df
# Out:
#                             Neighborhood
# 0                       Angelino Heights
# 1                           Angeles Mesa
# 2                          Angelus Vista
# 3                                 Arleta
# 4                      Arlington Heights
# 5                          Arts District
# 6                        Atwater Village
# 7                          Baldwin Hills
# 8                 Baldwin Hills/Crenshaw
# 9                        Baldwin Village
# 10                         Baldwin Vista
# 11                      Beachwood Canyon
# 12   Bel Air, Bel-Air or Bel Air Estates
# 13                       Benedict Canyon
# 14                         Beverly Crest
# 15                          Beverly Glen
# 16                         Beverly Grove
# 17             Beverly Hills Post Office
# 18                          Beverly Park
# 19                           Beverlywood
# 20                         Boyle Heights
# 21                             Brentwood
# 22                      Brentwood Circle
# 23                        Brentwood Glen
# 24                   Broadway-Manchester
# 25                             Brookside
# 26                           Bunker Hill
# 27                         Cahuenga Pass
# 28                           Canoga Park
# 29                     Canterbury Knolls
# 30                               Carthay
# 31                        Castle Heights
# 32                       Central-Alameda
# 33                          Central City
# 34                          Century City
# 35                            Chatsworth
# 36                   Chesterfield Square
# 37                         Cheviot Hills
# 38                             Chinatown
# 39                          Civic Center
# 40                              Crenshaw
# 41                       Crestwood Hills
# 42                          Cypress Park
# 43                               Del Rey
# 44                              Downtown
# 45                            Eagle Rock
# 46                     East Gate Bel Air
# 47                        East Hollywood
# 48                             Echo Park
# 49                              Edendale
# 50                             El Sereno
# 51                       Elysian Heights
# 52                          Elysian Park
# 53                        Elysian Valley
# 54                                Encino
# 55                       Exposition Park
# 56                    Faircrest Heights
# 57                               Fairfax
# 58                      Fashion District
# 59                Filipinotown, Historic
# 60                    Financial District
# 61                              Florence
# 62                       Flower District
# 63                        Franklin Hills
# 64                           Gallery Row
# 65                              Garvanza
# 66                         Glassell Park
# 67                         Gramercy Park
# 68                         Granada Hills
# 69                         Green Meadows
# 70                         Griffith Park
# 71                          Hancock Park
# 72                           Harbor City
# 73                        Harbor Gateway
# 74                       Harvard Heights
# 75                          Harvard Park
# 76                                Hermon
# 77                         Highland Park
# 78                         Historic Core
# 79                             Hollywood
# 80                        Hollywood Dell
# 81                       Hollywood Hills
# 82                  Hollywood Hills West
# 83                          Holmby Hills
# 84                             Hyde Park
# 85                        Jefferson Park
# 86                      Jewelry District
# 87                        Kinney Heights
# 88                             Koreatown
# 89                                Ladera
# 90                      Lafayette Square
# 91                           Lake Balboa
# 92                     Lake View Terrace
# 93                             Larchmont
# 94                         Laurel Canyon
# 95                          Leimert Park
# 96                       Lincoln Heights
# 97                        Little Armenia
# 98                       Little Ethiopia
# 99                          Little Italy
# 100                         Little Tokyo
# 101                            Los Feliz
# 102                    Manchester Square
# 103                    Mandeville Canyon
# 104                     Marina Peninsula
# 105                            Mar Vista
# 106                         Melrose Hill
# 107                             Mid-City
# 108                         Mid-Wilshire
# 109                         Miracle Mile
# 110                        Mission Hills
# 111                    Montecito Heights
# 112                       Monterey Hills
# 113                        Mount Olympus
# 114                     Mount Washington
# 115                        Naud Junction
# 116                       Nichols Canyon
# 117                   NoHo Arts District
# 118                          North Hills
# 119                      North Hollywood
# 120                           Northridge
# 121                North University Park
# 122                    Old Bank District
# 123                      Outpost Estates
# 124                    Pacific Palisades
# 125                              Pacoima
# 126                                Palms
# 127                        Panorama City
# 128                         Park La Brea
# 129                      Picfair Village
# 130                       Pico Robertson
# 131                           Pico-Union
# 132                        Playa del Rey
# 133                          Playa Vista
# 134                         Porter Ranch
# 135                          Rancho Park
# 136                               Reseda
# 137                      Reynier Village
# 138                          Rose Hills
# 139                        Rustic Canyon
# 140                            San Pedro
# 141                             Sawtelle
# 142                         Shadow Hills
# 143                         Sherman Oaks
# 144                      Sherman Village
# 145                          Silver Lake
# 146                             Skid Row
# 147                        Solano Canyon
# 148                          Sonoratown
# 149              South Central, Historic
# 150                           South Park
# 151                      South Robertson
# 152                     Spaulding Square
# 153                          Studio City
# 154                              Sunland
# 155                      Sunset Junction
# 156                           Sun Valley
# 157                               Sylmar
# 158                              Tarzana
# 159                      Terminal Island
# 160                            Thai Town
# 161                          Toluca Lake
# 162                         Toy District
# 163                              Tujunga
# 164                     University Hills
# 165                      University Park
# 166               University Park, North
# 167                          Valley Glen
# 168                       Valley Village
# 169                             Van Nuys
# 170                               Venice
# 171                       Vermont Knolls
# 172                      Vermont-Slauson
# 173                       Vermont Square
# 174                        Vermont Vista
# 175                       Victor Heights
# 176                        Victoria Park
# 177                        Village Green
# 178                   Warehouse District
# 179                        Warner Center
# 180                                Watts
# 181                           West Adams
# 182                          Westchester
# 183                             Westdale
# 184                      Western Heights
# 185                           West Hills
# 186                             Westlake
# 187                     West Los Angeles
# 188                     Westside Village
# 189                             Westwood
# 190                     Westwood Village
# 191                      Whitley Heights
# 192                   Wholesale District
# 193                           Wilmington
# 194                      Wilshire Center
# 195                        Wilshire Park
# 196                       Windsor Square
# 197                             Winnetka
# 198                       Woodland Hills
# 199                       Yucca Corridor

# %% [markdown]
# ## 3. Geographical coordinates

# %%
# define a function to get coordinates
def get_latlng(neighborhood):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, los angeles, USA '.format(neighborhood))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# %%
# call the function to get the coordinates, store in a new list using list comprehension
coords = [ get_latlng(neighborhood) for neighborhood in neighbor_df["Neighborhood"].tolist() ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-3ed6dc90501e> in <module>()
#       1 # call the function to get the coordinates, store in a new list using list comprehension
# ----> 2 coords = [ get_latlng(neighborhood) for neighborhood in neighbor_df["Neighborhood"].tolist() ]
#
# <ipython-input-79-3ed6dc90501e> in <listcomp>(.0)
#       1 # call the function to get the coordinates, store in a new list using list comprehension
# ----> 2 coords = [ get_latlng(neighborhood) for neighborhood in neighbor_df["Neighborhood"].tolist() ]
#
# <ipython-input-77-152b457c0161> in get_latlng(neighborhood)
#       5     # loop until you get the coordinates
#       6     while(lat_lng_coords is None):
# ----> 7         g = geocoder.arcgis('{}, los angeles, USA '.format(neighborhood))
#       8         lat_lng_coords = g.latlng
#       9     return lat_lng_coords
#
# NameError: name 'geocoder' is not defined
